# %%
pip install -r requirements.txt
# Out:
# Collecting langchain-community (from -r requirements.txt (line 1))
#   Downloading langchain_community-0.3.14-py3-none-any.whl.metadata (2.9 kB)
# Collecting langgraph (from -r requirements.txt (line 2))
#   Downloading langgraph-0.2.62-py3-none-any.whl.metadata (15 kB)
# Collecting langchain-anthropic (from -r requirements.txt (line 3))
#   Downloading langchain_anthropic-0.3.1-py3-none-any.whl.metadata (2.3 kB)
# Collecting tavily-python (from -r requirements.txt (line 4))
#   Downloading tavily_python-0.5.0-py3-none-any.whl.metadata (11 kB)
# Collecting langgraph-checkpoint-sqlite (from -r requirements.txt (line 5))
#   Downloading langgraph_checkpoint_sqlite-2.0.1-py3-none-any.whl.metadata (3.0 kB)
# Collecting langchain-openai (from -r requirements.txt (line 6))
#   Downloading langchain_openai-0.3.0-py3-none-any.whl.metadata (2.7 kB)
# Requirement already satisfied: PyYAML>=5.3 in /usr/local/lib/python3.10/dist-packages (from langchain-community->-r requirements.txt (line 1)) (6.0.2)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /usr/local/lib/python3.10/dist-packages (from langchain-community->-r requirements.txt (line 1)) (2.0.36)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /usr/local/lib/python3.10/dist-packages (from langchain-community->-r requirements.txt (line 1)) (3.11.11)
# Collecting dataclasses-json<0.7,>=0.5.7 (from langchain-community->-r requirements.txt (line 1))
#   Downloading dataclasses_json-0.6.7-py3-none-any.whl.metadata (25 kB)
# Collecting httpx-sse<0.5.0,>=0.4.0 (from langchain-community->-r requirements.txt (line 1))
#   Downloading httpx_sse-0.4.0-py3-none-any.whl.metadata (9.0 kB)
# Requirement already satisfied: langchain<0.4.0,>=0.3.14 in /usr/local/lib/python3.10/dist-packages (from langchain-community->-r requirements.txt (line 1)) (0.3.14)
# Requirement already satisfied: langchain-core<0.4.0,>=0.3.29 in /usr/local/lib/python3.10/dist-packages (from langchain-community->-r requirements.txt (line 1)) (0.3.29)
# Requirement already satisfied: langsmith<0.3,>=0.1.125 in /usr/local/lib/python3.10/dist-packages (from langchain-community->-r requirements.txt (line 1)) (0.2.10)
# Requirement already satisfied: numpy<2,>=1.22.4 in /usr/local/lib/python3.10/dist-packages (from langchain-community->-r requirements.txt (line 1)) (1.26.4)
# Collecting pydantic-settings<3.0.0,>=2.4.0 (from langchain-community->-r requirements.txt (line 1))
#   Downloading pydantic_settings-2.7.1-py3-none-any.whl.metadata (3.5 kB)
# Requirement already satisfied: requests<3,>=2 in /usr/local/lib/python3.10/dist-packages (from langchain-community->-r requirements.txt (line 1)) (2.32.3)
# Requirement already satisfied: tenacity!=8.4.0,<10,>=8.1.0 in /usr/local/lib/python3.10/dist-packages (from langchain-community->-r requirements.txt (line 1)) (9.0.0)
# Collecting langgraph-checkpoint<3.0.0,>=2.0.4 (from langgraph->-r requirements.txt (line 2))
#   Downloading langgraph_checkpoint-2.0.9-py3-none-any.whl.metadata (4.6 kB)
# Collecting langgraph-sdk<0.2.0,>=0.1.42 (from langgraph->-r requirements.txt (line 2))
#   Downloading langgraph_sdk-0.1.51-py3-none-any.whl.metadata (1.8 kB)
# Collecting anthropic<1,>=0.41.0 (from langchain-anthropic->-r requirements.txt (line 3))
#   Downloading anthropic-0.42.0-py3-none-any.whl.metadata (23 kB)
# Requirement already satisfied: defusedxml<0.8.0,>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from langchain-anthropic->-r requirements.txt (line 3)) (0.7.1)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /usr/local/lib/python3.10/dist-packages (from langchain-anthropic->-r requirements.txt (line 3)) (2.10.4)
# Collecting tiktoken>=0.5.1 (from tavily-python->-r requirements.txt (line 4))
#   Downloading tiktoken-0.8.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.6 kB)
# Requirement already satisfied: httpx in /usr/local/lib/python3.10/dist-packages (from tavily-python->-r requirements.txt (line 4)) (0.28.1)
# Collecting aiosqlite<0.21.0,>=0.20.0 (from langgraph-checkpoint-sqlite->-r requirements.txt (line 5))
#   Downloading aiosqlite-0.20.0-py3-none-any.whl.metadata (4.3 kB)
# Requirement already satisfied: openai<2.0.0,>=1.58.1 in /usr/local/lib/python3.10/dist-packages (from langchain-openai->-r requirements.txt (line 6)) (1.59.4)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community->-r requirements.txt (line 1)) (2.4.4)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community->-r requirements.txt (line 1)) (1.3.2)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community->-r requirements.txt (line 1)) (4.0.3)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community->-r requirements.txt (line 1)) (24.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community->-r requirements.txt (line 1)) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community->-r requirements.txt (line 1)) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community->-r requirements.txt (line 1)) (0.2.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community->-r requirements.txt (line 1)) (1.18.3)
# Requirement already satisfied: typing_extensions>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiosqlite<0.21.0,>=0.20.0->langgraph-checkpoint-sqlite->-r requirements.txt (line 5)) (4.12.2)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.10/dist-packages (from anthropic<1,>=0.41.0->langchain-anthropic->-r requirements.txt (line 3)) (3.7.1)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.10/dist-packages (from anthropic<1,>=0.41.0->langchain-anthropic->-r requirements.txt (line 3)) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from anthropic<1,>=0.41.0->langchain-anthropic->-r requirements.txt (line 3)) (0.8.2)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from anthropic<1,>=0.41.0->langchain-anthropic->-r requirements.txt (line 3)) (1.3.1)
# Collecting marshmallow<4.0.0,>=3.18.0 (from dataclasses-json<0.7,>=0.5.7->langchain-community->-r requirements.txt (line 1))
#   Downloading marshmallow-3.25.1-py3-none-any.whl.metadata (7.3 kB)
# Collecting typing-inspect<1,>=0.4.0 (from dataclasses-json<0.7,>=0.5.7->langchain-community->-r requirements.txt (line 1))
#   Downloading typing_inspect-0.9.0-py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx->tavily-python->-r requirements.txt (line 4)) (2024.12.14)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.10/dist-packages (from httpx->tavily-python->-r requirements.txt (line 4)) (1.0.7)
# Requirement already satisfied: idna in /usr/local/lib/python3.10/dist-packages (from httpx->tavily-python->-r requirements.txt (line 4)) (3.10)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.10/dist-packages (from httpcore==1.*->httpx->tavily-python->-r requirements.txt (line 4)) (0.14.0)
# Requirement already satisfied: langchain-text-splitters<0.4.0,>=0.3.3 in /usr/local/lib/python3.10/dist-packages (from langchain<0.4.0,>=0.3.14->langchain-community->-r requirements.txt (line 1)) (0.3.5)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /usr/local/lib/python3.10/dist-packages (from langchain-core<0.4.0,>=0.3.29->langchain-community->-r requirements.txt (line 1)) (1.33)
# Requirement already satisfied: packaging<25,>=23.2 in /usr/local/lib/python3.10/dist-packages (from langchain-core<0.4.0,>=0.3.29->langchain-community->-r requirements.txt (line 1)) (24.2)
# Requirement already satisfied: msgpack<2.0.0,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from langgraph-checkpoint<3.0.0,>=2.0.4->langgraph->-r requirements.txt (line 2)) (1.1.0)
# Requirement already satisfied: orjson>=3.10.1 in /usr/local/lib/python3.10/dist-packages (from langgraph-sdk<0.2.0,>=0.1.42->langgraph->-r requirements.txt (line 2)) (3.10.13)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from langsmith<0.3,>=0.1.125->langchain-community->-r requirements.txt (line 1)) (1.0.0)
# Requirement already satisfied: tqdm>4 in /usr/local/lib/python3.10/dist-packages (from openai<2.0.0,>=1.58.1->langchain-openai->-r requirements.txt (line 6)) (4.67.1)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain-anthropic->-r requirements.txt (line 3)) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in /usr/local/lib/python3.10/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain-anthropic->-r requirements.txt (line 3)) (2.27.2)
# Collecting python-dotenv>=0.21.0 (from pydantic-settings<3.0.0,>=2.4.0->langchain-community->-r requirements.txt (line 1))
#   Downloading python_dotenv-1.0.1-py3-none-any.whl.metadata (23 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchain-community->-r requirements.txt (line 1)) (3.4.1)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchain-community->-r requirements.txt (line 1)) (2.3.0)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from SQLAlchemy<3,>=1.4->langchain-community->-r requirements.txt (line 1)) (3.1.1)
# Requirement already satisfied: regex>=2022.1.18 in /usr/local/lib/python3.10/dist-packages (from tiktoken>=0.5.1->tavily-python->-r requirements.txt (line 4)) (2024.11.6)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.5.0->anthropic<1,>=0.41.0->langchain-anthropic->-r requirements.txt (line 3)) (1.2.2)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.10/dist-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.4.0,>=0.3.29->langchain-community->-r requirements.txt (line 1)) (3.0.0)
# Collecting mypy-extensions>=0.3.0 (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain-community->-r requirements.txt (line 1))
#   Downloading mypy_extensions-1.0.0-py3-none-any.whl.metadata (1.1 kB)
# Downloading langchain_community-0.3.14-py3-none-any.whl (2.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 25.4 MB/s eta 0:00:00
# Downloading langgraph-0.2.62-py3-none-any.whl (138 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 138.2/138.2 kB 11.2 MB/s eta 0:00:00
# Downloading langchain_anthropic-0.3.1-py3-none-any.whl (22 kB)
# Downloading tavily_python-0.5.0-py3-none-any.whl (14 kB)
# Downloading langgraph_checkpoint_sqlite-2.0.1-py3-none-any.whl (12 kB)
# Downloading langchain_openai-0.3.0-py3-none-any.whl (54 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.2/54.2 kB 4.3 MB/s eta 0:00:00
# Downloading aiosqlite-0.20.0-py3-none-any.whl (15 kB)
# Downloading anthropic-0.42.0-py3-none-any.whl (203 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 203.4/203.4 kB 12.6 MB/s eta 0:00:00
# Downloading dataclasses_json-0.6.7-py3-none-any.whl (28 kB)
# Downloading httpx_sse-0.4.0-py3-none-any.whl (7.8 kB)
# Downloading langgraph_checkpoint-2.0.9-py3-none-any.whl (37 kB)
# Downloading langgraph_sdk-0.1.51-py3-none-any.whl (44 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.7/44.7 kB 3.8 MB/s eta 0:00:00
# Downloading pydantic_settings-2.7.1-py3-none-any.whl (29 kB)
# Downloading tiktoken-0.8.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 55.0 MB/s eta 0:00:00
# Downloading marshmallow-3.25.1-py3-none-any.whl (49 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.6/49.6 kB 4.2 MB/s eta 0:00:00
# Downloading python_dotenv-1.0.1-py3-none-any.whl (19 kB)
# Downloading typing_inspect-0.9.0-py3-none-any.whl (8.8 kB)
# Downloading mypy_extensions-1.0.0-py3-none-any.whl (4.7 kB)
# Installing collected packages: python-dotenv, mypy-extensions, marshmallow, httpx-sse, aiosqlite, typing-inspect, tiktoken, tavily-python, pydantic-settings, langgraph-sdk, dataclasses-json, anthropic, langgraph-checkpoint, langchain-openai, langchain-anthropic, langgraph-checkpoint-sqlite, langgraph, langchain-community
# Successfully installed aiosqlite-0.20.0 anthropic-0.42.0 dataclasses-json-0.6.7 httpx-sse-0.4.0 langchain-anthropic-0.3.1 langchain-community-0.3.14 langchain-openai-0.3.0 langgraph-0.2.62 langgraph-checkpoint-2.0.9 langgraph-checkpoint-sqlite-2.0.1 langgraph-sdk-0.1.51 marshmallow-3.25.1 mypy-extensions-1.0.0 pydantic-settings-2.7.1 python-dotenv-1.0.1 tavily-python-0.5.0 tiktoken-0.8.0 typing-inspect-0.9.0

# %% [markdown]
# Many of the applications you build with LangChain will contain multiple steps with multiple invocations of LLM calls. As these applications get more and more complex, it becomes crucial to be able to inspect what exactly is going on inside your chain or agent. The best way to do this is with LangSmith.

# %%
import getpass
import os

os.environ["TAVILY_API_KEY"] = getpass.getpass()
# Out:
# ··········

# %%
from langchain_community.tools.tavily_search import TavilySearchResults

search = TavilySearchResults(max_results=2)
search_results = search.invoke("what is the weather in bhusawal, Maharashtra, India")
print(search_results)
# If we want, we can create other tools.
# Once we have all the tools we want, we can put them in a list that we will reference later.
tools = [search]
# Out:
# /usr/local/lib/python3.10/dist-packages/langsmith/client.py:256: LangSmithMissingAPIKeyWarning: API key must be provided when using hosted LangSmith API
#   warnings.warn(
# WARNING:langsmith.client:Failed to multipart ingest runs: langsmith.utils.LangSmithAuthError: Authentication failed for https://api.smith.langchain.com/runs/multipart. HTTPError('401 Client Error: Unauthorized for url: https://api.smith.langchain.com/runs/multipart', '{"detail":"Invalid token"}')trace=849d1e51-55ff-4f61-b2c2-3012d5c5a80b,id=849d1e51-55ff-4f61-b2c2-3012d5c5a80b
# [{'url': 'https://www.weatherapi.com/', 'content': "{'location': {'name': 'Bhusawal', 'region': 'Maharashtra', 'country': 'India', 'lat': 21.05, 'lon': 75.7667, 'tz_id': 'Asia/Kolkata', 'localtime_epoch': 1736855574, 'localtime': '2025-01-14 17:22'}, 'current': {'last_updated_epoch': 1736855100, 'last_updated': '2025-01-14 17:15', 'temp_c': 27.6, 'temp_f': 81.7, 'is_day': 1, 'condition': {'text': 'Sunny', 'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png', 'code': 1000}, 'wind_mph': 8.7, 'wind_kph': 14.0, 'wind_degree': 42, 'wind_dir': 'NE', 'pressure_mb': 1012.0, 'pressure_in': 29.89, 'precip_mm': 0.0, 'precip_in': 0.0, 'humidity': 40, 'cloud': 8, 'feelslike_c': 27.5, 'feelslike_f': 81.4, 'windchill_c': 27.6, 'windchill_f': 81.7, 'heatindex_c': 27.5, 'heatindex_f': 81.4, 'dewpoint_c': 12.8, 'dewpoint_f': 55.1, 'vis_km': 10.0, 'vis_miles': 6.0, 'uv': 0.0, 'gust_mph': 12.8, 'gust_kph': 20.7}}"}, {'url': 'https://www.worldweatheronline.com/bhusawal-weather/maharashtra/in.aspx', 'content': 'World weather; India; Maharashtra; Bhusawal; Weather . Hourly. All Mon 13/01 Tue 14/01 Wed 15/01 Thu 16/01 Fri 17/01 Sat 18/01 Sun 19/01 Mon 20/01 Tue 21/01 Wed 22/01 Thu 23/01 Fri 24/01 Sat 25/01 Sun 26/01. ... Bhusawal, India weather forecasted for the next 10 days will have maximum temperature of 33°c / 92°f on Sat 18.'}]

# %%
from langchain_community.tools.tavily_search import TavilySearchResults

search = TavilySearchResults(max_results=2)
search_results = search.invoke("wikipedia fibonacci series")
print(search_results)
# Out:
# [{'url': 'https://simple.wikipedia.org/wiki/Fibonacci_number', 'content': 'A Fibonacci spiral created by drawing a line through the squares in the Fibonacci tiling; this one uses squares of sizes 1, 1, 2, 3, 5, 8, 13, 21, and 34; see Golden spiral. The Fibonacci numbers are a sequence of numbers in mathematics named after Leonardo of Pisa, known as Fibonacci.Fibonacci wrote a book in 1202, called Liber Abaci ("Book of Calculation"), which introduced the number'}, {'url': 'https://en.wikipedia.org/wiki/Fibonacci_sequence', 'content': 'The Fibonacci spiral: an approximation of the golden spiral created by drawing circular arcs connecting the opposite corners of squares in the Fibonacci tiling (see preceding image). The Fibonacci numbers may be defined by the recurrence relation [7] =, =, and = + for n > 1.. Under some older definitions, the value = is omitted, so that the sequence starts with = =, and the recurrence = + is'}]
